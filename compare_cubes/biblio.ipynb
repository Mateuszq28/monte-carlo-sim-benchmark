# %%
bib = []
# 0-9
bib.append('A. van der Gijp i in., „Increasing Authenticity of Simulation-Based Assessment in Diagnostic Radiology”, Simulation in Healthcare: The Journal of the Society for Simulation in Healthcare, t. 12, nr 6. Ovid Technologies (Wolters Kluwer Health), s. 377–384, grudz. 2017. doi: 10.1097/sih.0000000000000278.')
bib.append('J. Y. Chen i in., „Non-invasive blood glucose measurement of 95% certainty by pressure regulated Mid-IR”, Talanta, t. 197. Elsevier BV, s. 211–217, maj 2019. doi: 10.1016/j.talanta.2019.01.034.')
bib.append('K. Tökési, L. H. Yang, D. Bo, i Z. J. Ding, „Revision of optical properties of solids based on the reverse Monte Carlo analysis of reflection electron energy loss spectroscopy spectra”, Journal of Surface Analysis, t. 26, nr 2. Surface Analysis Society of Japan, s. 128–129, 2019. doi: 10.1384/jsa.26.128.')
bib.append('A. N. Bashkatov, E. A. Genina, V. I. Kochubey, i V. V. Tuchin, „Optical properties of human skin, subcutaneous and mucous tissues in the wavelength range from 400 to 2000 nm”, Journal of Physics D: Applied Physics, t. 38, nr 15. IOP Publishing, s. 2543–2555, lip. 22, 2005. doi: 10.1088/0022-3727/38/15/004.')
bib.append('A. J. Welch i M. J. C. van Gemert, Red., Optical-Thermal Response of Laser-Irradiated Tissue. Springer Netherlands, 2011. doi: 10.1007/978-90-481-8831-4.')
bib.append('E. Hecht, Optics. Boston: Pearson, 2017. ')
bib.append('D. O. Akpootu i in., „The Scattering and Absorption Coefficients of Atmospheric Soot in the Hygroscopicity of Urban Aerosols”, Dutse Journal of Pure and Applied Sciences, t. 9, nr 2b. African Journals Online (AJOL), s. 86–97, lip. 16, 2023. doi: 10.4314/dujopas.v9i2b.10.')
bib.append('L. Sipelgas, H. Arst, U. Raudsepp, T. Kõuts, and A. Lindfors, „Optical properties of coastal waters of northwestern Estonia: in situ measurements", 2004.')
bib.append('K. M. Aly and E. Esmail, „Refractive index of salt water: effect of temperature", Department of Engineering Mathematics and Physics, Faculty of Engineering, Alexandria University, Alexandria, Egypt, 1993.')
bib.append('T. Kono i J. Yamada, „In Vivo Measurement of Optical Properties of Human Skin for 450–800 nm and 950–1600 nm Wavelengths”, International Journal of Thermophysics, t. 40, nr 5. Springer Science and Business Media LLC, kwi. 26, 2019. doi: 10.1007/s10765-019-2515-3.')
# 10-19
bib.append('S. Akter, „Evaluation of light scattering and absorption properties of in vivo rat liver using a single-reflectance fiber probe during preischemia, ischemia–reperfusion, and postmortem", Journal of Biomedical Optics, vol. 20, no. 7, p. 076010, 2015.')
bib.append('H. Li, L. Lin, and S. Xie, „Refractive index of human whole blood with different types in the visible and near-infrared ranges", Biomedical Optics Laboratory, Department of Physics, Fujian Teachers University, China.')
bib.append('C. R. Simpson, M. Kohl, M. Essenpreis, i M. Cope, „Near-infrared optical properties ofex vivohuman skin and subcutaneous tissues measured using the Monte Carlo inversion technique”, Physics in Medicine and Biology, t. 43, nr 9. IOP Publishing, s. 2465–2478, wrz. 01, 1998. doi: 10.1088/0031-9155/43/9/003.')
bib.append('M. J. C. Van Gemert, S. L. Jacques, H. J. C. M. Sterenborg, i W. M. Star, „Skin optics”, IEEE Transactions on Biomedical Engineering, t. 36, nr 12. Institute of Electrical and Electronics Engineers (IEEE), s. 1146–1154, 1989. doi: 10.1109/10.42108.')
bib.append('R. R. Anderson and B. S. J. A. Parrish, „The Optics of Human Skin", Department of Dermatology, Harvard Medical School, Massachusetts General Hospital, Boston, Massachusetts, U.S.A., 1981.')
bib.append('"Dokumentacja biblioteki VisPy", VisPy developers, 2023. [Online]. Available: https://vispy.org/. [Accessed: Oct. 12, 2023].')
bib.append('"Repozytorium biblioteki VisPy", VisPy developers, 2023. [Online]. Available: https://github.com/vispy/vispy. [Accessed: Oct. 12, 2023].')
bib.append('J. D. Hunter, „Matplotlib: A 2D Graphics Environment”, Computing in Science &amp; Engineering, t. 9, nr 3. Institute of Electrical and Electronics Engineers (IEEE), s. 90–95, 2007. doi: 10.1109/mcse.2007.55.')
bib.append('J. Hunter, D. Dale, E. Firing, and M. Droettboom, „Dokumentacja biblioteki Matplotlib", Matplotlib development team, 2023. [Online]. Available: https://matplotlib.org/. [Accessed: Oct. 13, 2023].')
bib.append('"Repozytorium biblioteki NumPy", The Matplotlib development team, 2023. [Online]. Available: https://github.com/matplotlib/matplotlib. [Accessed: Oct. 13, 2023].')
# 20-29
bib.append('I. NumFOCUS, „Dokumentacja obiektu DataFrame", 2023. [Online]. Available: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html. [Accessed: Oct. 13, 2023].')
bib.append('I. NumFOCUS, „Dokumentacja biblioteki Pandas", 2023. [Online]. Available: https://pandas.pydata.org/docs/index.html. [Accessed: Oct. 13, 2023].')
bib.append('"Repozytorium biblioteki Pandas", NumFOCUS, Inc., 2023. [Online]. Available: https://github.com/pandas-dev/pandas. [Accessed: Oct. 13, 2023].')
bib.append('"Strona internetowa firmy NumFOCUS rozwijającej bibliotekę Pandas", NumFOCUS, Inc., 2023. [Online]. Available: https://numfocus.org/. [Accessed: Oct. 13, 2023].')
bib.append('W3C, „Portable Network Graphics (PNG) Specification (Third Edition)", Sep. 21, 2023. [Online]. Available: https://www.w3.org/TR/png-3/. [Accessed: Oct. 13, 2023].')
bib.append('Python Software Foundation, „Dokumentacja języka Python", Oct. 12, 2023. [Online]. Available: https://docs.python.org/3/. [Accessed: Oct. 14, 2023].')
bib.append('Free Software Foundation, Inc., „Dokumentacja Bash", 2008. [Online]. Available: https://devdocs.io/bash/. [Accessed: Oct. 14, 2023].')
bib.append('NumPy Developers, „Dokumentacja biblioteki NumPy", 2022. [Online]. Available: https://numpy.org/doc/stable/. [Accessed: Oct. 14, 2023]')
bib.append('NumPy Developers, „Dokumentacja - Permuted Congruential Generator (64-bit, PCG64)", 2022. [Online]. Available: https://numpy.org/doc/stable/reference/random/bit_generators/pcg64.html#permuted-congruential-generator-64-bit-pcg64. [Accessed: Oct. 14, 2023].')
bib.append('M. Bürmen, F. Pernuš, i P. Naglič, „MCDataset: a public reference dataset of Monte Carlo simulated quantities for multilayered and voxelated tissues computed by massively parallel PyXOpto Python package”, Journal of Biomedical Optics, t. 27, nr 08. SPIE-Intl Soc Optical Eng, kwi. 18, 2022. doi: 10.1117/1.jbo.27.8.083012.')
# 30-39
bib.append('Y. Jiang, S. L. Bugby, i J. E. Lees, „PMST: A custom Python-based Monte Carlo Simulation Tool for research and system development in portable pinhole gamma cameras”, Nuclear Instruments and Methods in Physics Research Section A: Accelerators, Spectrometers, Detectors and Associated Equipment, t. 1061. Elsevier BV, s. 169161, kwi. 2024. doi: 10.1016/j.nima.2024.169161.')
bib.append('J. D. Lindberg, „The composition and optical absorption coefficient of atmospheric particulate matter”, Optical and Quantum Electronics, t. 7, nr 3. Springer Science and Business Media LLC, s. 131–139, maj 1975. doi: 10.1007/bf00619587.')
bib.append('A. Roggan, M. Friebel, K. Dörschel, A. Hahn, i G. Müller, „Optical Properties of Circulating Human Blood in the Wavelength Range 400–2500 nm”, Journal of Biomedical Optics, t. 4, nr 1. SPIE-Intl Soc Optical Eng, s. 36, 1999. doi: 10.1117/1.429919.')
bib.append('V. V. Semak, A. Gerakis, i M. N. Shneider, „Measurement of temperature dependent absorption coefficient of water at 1064nm wavelength”, AIP Advances, t. 9, nr 8. AIP Publishing, sie. 01, 2019. doi: 10.1063/1.5085746.')
bib.append('M. Bürmen, F. Pernuš, i P. Naglič, „MCDataset: a public reference dataset of Monte Carlo simulated quantities for multilayered and voxelated tissues computed by massively parallel PyXOpto Python package”, Journal of Biomedical Optics, t. 27, nr 08. SPIE-Intl Soc Optical Eng, kwi. 18, 2022. doi: 10.1117/1.jbo.27.8.083012.')
bib.append('O. N. Vassiliev, Monte Carlo Methods for Radiation Transport. Springer International Publishing, 2017. doi: 10.1007/978-3-319-44141-2.')
bib.append('A. J. Welch and M. J. C. van Gemert, Eds., Optical-Thermal Response of Laser-Irradiated Tissue, 2011, ch. 5. Springer Netherlands. doi: 10.1007/978-90-481-8831-4.')
bib.append('A. P. Tran i S. L. Jacques, „Modeling voxel-based Monte Carlo light transport with curved and oblique boundary surfaces”, Journal of Biomedical Optics, t. 25, nr 02. SPIE-Intl Soc Optical Eng, s. 1, luty 25, 2020. doi: 10.1117/1.jbo.25.2.025001.')
bib.append('D. E. Knuth, The Art of Computer Programming, Volume 1 (3rd ed.): Fundamental Algorithms. Addison Wesley Longman Publishing Co., Inc., USA, 1997.')
bib.append('W. T. Vetterling, Numerical Recipes Example Book (c). Cambridge (Mass.): Cambridge University Press, 1995. ')
# 40-49
bib.append('"Medical Dictionary", The Free Dictionary. [Online]. Available: https://medical-dictionary.thefreedictionary.com/. [Accessed: Oct. 16, 2023].')
bib.append('"Broszura dla nauczycieli o tematyce optyki", [Online]. Available: https://zpe.gov.pl/pdf/Pmx9E7pqe. [Accessed: Oct. 16, 2023].')
bib.append('ISO/IEC 9899:2018, Programming Languages — C, 2018.')
bib.append('"C Documentation", cppreference.com. [Online]. Available: https://en.cppreference.com/w/c/language. [Accessed: Oct. 16, 2023].')
bib.append('"C Documentation", DevDocs. [Online]. Available: https://devdocs.io/c/. [Accessed: Oct. 16, 2023].')
bib.append('M. Miler, „monte-carlo-sim-python - repozytorium z własną implementacją symulacji światła metodą Monte Carlo w języku Python", GitHub. [Online]. Available: https://github.com/Mateuszq28/monte-carlo-sim-python. [Accessed: Oct. 16, 2023].')
bib.append('ECMA-404, The JSON Data Interchange Syntax. [Online]. Available: https://ecma-international.org/publications-and-standards/standards/ecma-404/. [Accessed: Oct. 16, 2023].')
bib.append('"W3Schools - JSON Introduction", W3Schools. [Online]. Available: https://www.w3schools.com/js/js_json_intro.asp. [Accessed: Oct. 16, 2023].')
bib.append('M. Miler, „CUBES - wyniki najważniejszych eksperymentów symulacji światła metodą Mone Carlo” Google Drive. [Online]. Available: https://1drv.ms/f/c/7871da7edeb06dcc/Ei70d6guE4lBgMsf6FgGbJsBUcYmqrgZFZZxBHvQeMgqBQ. [Accessed: Oct. 16, 2023].')
bib.append('T. L. Stedman, Stedman’s Medical Dictionary. Philadelphia: Lippincott Williams & Wilkins, 2006.')
# 50-59
bib.append('V. Sontea, I. Pocaznoi, D. Furtuna, A. Seryakov, V. Barun, i S. Dick, „Effects of the Low Level Light therapy on skin wound using LED”, 2013 E-Health and Bioengineering Conference (EHB), t. 100. IEEE, s. 1–4, lis. 2013. doi: 10.1109/ehb.2013.6707243.')
bib.append('P. Zhang i M. X. Wu, „A clinical review of phototherapy for psoriasis”, Lasers in Medical Science, t. 33, nr 1. Springer Science and Business Media LLC, s. 173–180, paź. 24, 2017. doi: 10.1007/s10103-017-2360-1.')
bib.append('T. Niu, Y. Tian, Q. Ren, L. Wei, X. Li, i Q. Cai, „Red Light Interferes in <scp>UVA</scp>‐Induced Photoaging of Human Skin Fibroblast Cells”, Photochemistry and Photobiology, t. 90, nr 6. Wiley, s. 1349–1358, sie. 18, 2014. doi: 10.1111/php.12316.')
bib.append('H. H. Kwon i in., „The clinical and histological effect of home-use, combination blue-red LED phototherapy for mild-to-moderate acne vulgaris in Korean patients: a double-blind, randomized controlled trial”, British Journal of Dermatology, t. 168, nr 5. Oxford University Press (OUP), s. 1088–1094, kwi. 25, 2013. doi: 10.1111/bjd.12186.')
bib.append('C. Lu i in., „Effects of low-level laser therapy on burning pain and quality of life in patients with burning mouth syndrome: a systematic review and meta-analysis”, BMC Oral Health, t. 23, nr 1. Springer Science and Business Media LLC, paź. 09, 2023. doi: 10.1186/s12903-023-03441-w.')
bib.append('T.-W. Hou, C.-C. Yang, T.-H. Lai, Y.-H. Wu, i C.-P. Yang, „Light Therapy in Chronic Migraine”, Current Pain and Headache Reports, t. 28, nr 7. Springer Science and Business Media LLC, s. 621–626, cze. 12, 2024. doi: 10.1007/s11916-024-01258-y.')
bib.append('P. Xiao i in., „Effect of Light Therapy on Cancer-Related Fatigue: A Systematic Review and Meta-Analysis”, Journal of Pain and Symptom Management, t. 63, nr 2. Elsevier BV, s. e188–e202, luty 2022. doi: 10.1016/j.jpainsymman.2021.09.010.')
bib.append('A. van Maanen, A. M. Meijer, K. B. van der Heijden, i F. J. Oort, „The effects of light therapy on sleep problems: A systematic review and meta-analysis”, Sleep Medicine Reviews, t. 29. Elsevier BV, s. 52–62, paź. 2016. doi: 10.1016/j.smrv.2015.08.009.')
bib.append('E. Pjrek i in., „The Efficacy of Light Therapy in the Treatment of Seasonal Affective Disorder: A Meta-Analysis of Randomized Controlled Trials”, Psychotherapy and Psychosomatics, t. 89, nr 1. S. Karger AG, s. 17–24, paź. 01, 2019. doi: 10.1159/000502891.')
bib.append('L. Tao i in., „Light therapy in non-seasonal depression: An update meta-analysis”, Psychiatry Research, t. 291. Elsevier BV, s. 113247, wrz. 2020. doi: 10.1016/j.psychres.2020.113247.')
# 60-69
bib.append('S. Dallaspezia i F. Benedetti, „Antidepressant light therapy for bipolar patients: A meta-analyses”, Journal of Affective Disorders, t. 274. Elsevier BV, s. 943–948, wrz. 2020. doi: 10.1016/j.jad.2020.05.104.')
bib.append('A. Brouwer i in., „Light therapy: is it safe for the eyes?”, Acta Psychiatrica Scandinavica, t. 136, nr 6. Wiley, s. 534–548, wrz. 10, 2017. doi: 10.1111/acps.12785.')
bib.append('P. Avci, A. Gupta, M. Sadasivam, D. Vecchio, Z. Pam, N. Pam, and M. R. Hamblin, „Low-level laser (light) therapy (LLLT) in skin: stimulating, healing, restoring", Seminars in Cutaneous Medicine and Surgery, vol. 32, no. 1, pp. 41–52, 2013.')
bib.append('"Monte Carlo Methods in Practice", Scratchapixel. [Online]. Available: https://www.scratchapixel.com/lessons/mathematics-physics-for-computer-graphics/monte-carlo-methods-in-practice/monte-carlo-simulation.html. [Accessed: Oct. 16, 2023].')
bib.append('"Monte Carlo Simulation” MarbleScience, YouTube. [Online]. Available: https://www.youtube.com/watch?v=7ESK5SaP-bc. [Accessed: Oct. 16, 2023].')
bib.append('"Funkcja obliqueslice programu MATLAB", MathWorks. [Online]. Available: https://www.mathworks.com/help/images/ref/obliqueslice.html#mw_dd35cbdb-0566-4cd9-8a4f-31d452f3b621. [Accessed: Oct. 16, 2023].')
bib.append('N. Metropolis, „The beginning of the Monte Carlo method", Los Alamos Science, vol. 15, no. Special issue, pp. 125–130, 1987.')
bib.append('R. D. Richtmyer and J. von Neumann, „Statistical methods in neutron diffusion", Los Alamos Scientific Laboratory Report LAMS-551, Los Alamos, 1947.')
bib.append('R. Eckhardt, „San Ulam, John von Neumann, and the Monte Carlo method", 1987.')
bib.append('E. Sergè, From X-Rays to Quarks: Modern Physicists and Their Discoveries. Dover, Mineola, NY, 2007.')
# 70-79
bib.append('J. Baro, J. Sempau, J. M. Fernandez-Varea, and F. Salvat, „PENELOPE: an algorithm for Monte Carlo simulation of the penetration and energy loss of electrons and positrons in matter", Nuclear Instruments and Methods in Physics Research Section B, vol. 100, no. 1, pp. 31–46, 1995.')
bib.append('N. Metropolis i S. Ulam, „The Monte Carlo Method”, Journal of the American Statistical Association, t. 44, nr 247. Informa UK Limited, s. 335–341, wrz. 1949. doi: 10.1080/01621459.1949.10483310.')
bib.append('A. Marrs, P. Shirley, and I. Wald, Eds., Ray Tracing Gems II: Next Generation Real-Time Rendering with DXR, Vulkan, and OptiX, 104.')
bib.append('P. Comninos, Mathematical and Computer Programming Techniques for Computer Graphics. London: Springer London, 2010.')
bib.append('"Marching Cubes", Wikipedia. [Online]. Available: https://en.wikipedia.org/wiki/Marching_cubes. [Accessed: Oct. 16, 2023].')
bib.append('W. E. Lorensen i H. E. Cline, „Marching cubes: A high resolution 3D surface construction algorithm”, Proceedings of the 14th annual conference on Computer graphics and interactive techniques. ACM, sie. 1987. doi: 10.1145/37401.37422.')
bib.append('"Marching Cubes Animation” Algorithms Visualized, YouTube. [Online]. Available: https://www.youtube.com/watch?v=B_xk71YopsA. [Accessed: Oct. 16, 2023].')
bib.append('"Why I'm Using Wave Function Collapse for Procedural Terrain | Unity Devlog” DV Gen, YouTube. [Online]. Available: https://www.youtube.com/watch?v=20KHNA9jTsE&list=PLWviGNkmY14wquTDA46Ycjq_p-B2Cew8S&index=3&t=4s. [Accessed: Oct. 16, 2023].')
bib.append('D. Williamson, „MarchingCubes.js” [Online]. Available: https://github.com/dwilliamson/MarchingCubes.js. [Accessed: Oct. 16, 2023]')
bib.append('L. Wang and S. L. Jacques, „Monte Carlo Modeling of Light Transport in Multi-layered Tissues in Standard C", Optical Imaging Laboratory, Biomedical Engineering Program, Texas A&M University, College Station, TX 77843-3120, [Online]. Available: http://biomed.tamu.edu/~lw](https://omlc.org/software/mc/man_mcml.pdf. [Accessed: Oct. 16, 2023].')
# 80-89
bib.append('"Symulacja MC321", OMLC. [Online]. Available: https://omlc.org/classroom/ece532/class4/ssmc/index.html. [Accessed: Oct. 16, 2023].')
bib.append('"Symulacja MCXYZ", OMLC. [Online]. Available: https://omlc.org/software/mc/mcxyz/index.html. [Accessed: Oct. 16, 2023].')
bib.append('"Symulacja MCML", OMLC. [Online]. Available: https://omlc.org/software/mc/mcml-src/index.html. [Accessed: Oct. 16, 2023].')
bib.append('OMLC. [Online]. Available: https://omlc.org/software/mc/. [Accessed: Oct. 16, 2023]')
bib.append('M. Keijzer, S. L. Jacques, S. A. Prahl, i A. J. Welch, „Light distributions in artery tissue: Monte Carlo simulations for finite‐diameter laser beams”, Lasers in Surgery and Medicine, t. 9, nr 2. Wiley, s. 148–154, sty. 1989. doi: 10.1002/lsm.1900090210.')
bib.append('Octave. [Online]. Available: https://octave.org/. [Accessed: Oct. 16, 2023].')
bib.append('"MATLAB” MathWorks. [Online]. Available: https://www.mathworks.com/products/matlab.html. [Accessed: Oct. 16, 2023]')
bib.append('"PyTissueOptics", DCC-Lab, GitHub. [Online]. Available: https://github.com/DCC-Lab/PyTissueOptics. [Accessed: Oct. 16, 2023].')
bib.append('"PyXOpto", xopto, GitHub. [Online]. Available: https://github.com/xopto/pyxopto. [Accessed: Oct. 16, 2023].')
bib.append('M. Bürmen, F. Pernuš, i P. Naglič, „MCDataset: a public reference dataset of Monte Carlo simulated quantities for multilayered and voxelated tissues computed by massively parallel PyXOpto Python package”, Journal of Biomedical Optics, t. 27, nr 08. SPIE-Intl Soc Optical Eng, kwi. 18, 2022. doi: 10.1117/1.jbo.27.8.083012.')
# 90-99
bib.append('P. Naglič, F. Pernuš, B. Likar, i M. Bürmen, „Limitations of the commonly used simplified laterally uniform optical fiber probe-tissue interface in Monte Carlo simulations of diffuse reflectance”, Biomedical Optics Express, t. 6, nr 10. Optica Publishing Group, s. 3973, wrz. 11, 2015. doi: 10.1364/boe.6.003973.')
bib.append('P. Naglič, F. Pernuš, B. Likar, i M. Bürmen, „Lookup table-based sampling of the phase function for Monte Carlo simulations of light propagation in turbid media”, Biomedical Optics Express, t. 8, nr 3. Optica Publishing Group, s. 1895, luty 28, 2017. doi: 10.1364/boe.8.001895.')
bib.append('"Kod źródłowy symulacji Tiny", OMLC. [Online]. Available: https://omlc.org/software/mc/tiny_mc.c. [Accessed: Oct. 16, 2023].')
bib.append('M. Miler, „monte-carlo-sim-benchmark - repozytorium wykorzystane do porównywania wyników symulacji” GitHub. [Online]. Available: https://github.com/Mateuszq28/monte-carlo-sim-benchmark. [Accessed: Oct. 16, 2023].')
bib.append('"Funkcja z transformacją Box-Cox” SciPy. [Online]. Available: https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.boxcox.html. [Accessed: Oct. 16, 2023].')
bib.append('"Funkcja z transformacją Yeo-Johnson” SciPy. [Online]. Available: https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.yeojohnson.html. [Accessed: Oct. 16, 2023].')
bib.append('"QuantileTransformer” Scikit-learn. [Online]. Available: https://scikit-learn.org/dev/modules/generated/sklearn.preprocessing.QuantileTransformer.html [Accessed: Oct. 16, 2023].')

# %%
# for b in bib:
    # print(b)

# %%
asd"ads
asd„sdf
asd”sd
