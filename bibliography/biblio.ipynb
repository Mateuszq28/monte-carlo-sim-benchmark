# %% [markdown]
# # old bib

# %%
import numpy as np
from collections import Counter

# %%
for v in omit_id:
    if v in filtered_num_old_arr:
        print(v)

# %%
print(filtered_num_old_arr)
# Out:
# ['[901]' '[903]' '[904]' '[905]' '[906]' '[907]' '[908]' '[909]' '[910]'
#  '[911]' '[912]' '[913]' '[914]' '[915]' '[916]' '[917]' '[918]' '[919]'
#  '[920]' '[921]' '[922]' '[923]' '[924]' '[925]' '[926]' '[927]' '[928]'
#  '[929]' '[932]' '[933]' '[934]' '[936]' '[937]' '[938]' '[941]' '[942]'
#  '[943]' '[944]' '[945]' '[947]' '[948]' '[951]' '[952]' '[953]' '[954]'
#  '[955]' '[956]' '[957]' '[958]' '[959]' '[960]' '[961]' '[962]' '[963]'
#  '[964]' '[965]' '[966]' '[967]' '[968]' '[969]' '[970]' '[971]' '[972]'
#  '[973]' '[974]' '[975]' '[976]' '[977]' '[978]' '[979]' '[980]' '[981]'
#  '[982]' '[983]' '[984]' '[985]' '[986]' '[987]' '[988]' '[989]' '[990]'
#  '[991]' '[992]' '[993]' '[995]' '[996]' '[997]' '[998]' '[999]' '[100]'
#  '[101]' '[102]']

# %%
ab = np.array(['a', 'A', 'b', 'B'])
sort_index = np.argsort(ab)
ab[sort_index]
# Out:
# array(['A', 'B', 'a', 'b'], dtype='<U1')

# %%
sorted(['a', 'A', 'b', 'B'])
# Out:
# ['A', 'B', 'a', 'b']

# %%
for n2, b2 in zip(new_num_arr, sorted_bib_arr):
    # print(f'{n2} {b2}')
    # print(f'{b2}')
# Out:
#   Cell In[1], line 3
#     # print(f'{b2}')
#                     ^
# SyntaxError: incomplete input

# %%
doi: 10.1088/0022-3727/38/15/004

# %%
for n1, n2 in zip(sorted_num_old_arr, new_num_arr):
    print(f'{n1[1:-1]} {n2}')
# Out:
# 907 [1]
# 911 [2]
# 977 [3]
# 909 [4]
# 998 [5]
# 915 [6]
# 963 [7]
# 971 [8]
# 904 [9]
# 942 [10]
# 962 [11]
# 990 [12]
# 943 [13]
# 974 [14]
# 999 [15]
# 944 [16]
# 961 [17]
# 988 [18]
# 945 [19]
# 978 [20]
# 969 [21]
# 947 [22]
# 927 [23]
# 100 [24]
# 906 [25]
# 956 [26]
# 918 [27]
# 919 [28]
# 985 [29]
# 910 [30]
# 954 [31]
# 912 [32]
# 932 [33]
# 976 [34]
# 955 [35]
# 965 [36]
# 973 [37]
# 987 [38]
# 966 [39]
# 920 [40]
# 967 [41]
# 972 [42]
# 991 [43]
# 992 [44]
# 953 [45]
# 921 [46]
# 923 [47]
# 924 [48]
# 922 [49]
# 928 [50]
# 929 [51]
# 986 [52]
# 984 [53]
# 981 [54]
# 983 [55]
# 982 [56]
# 993 [57]
# 102 [58]
# 959 [59]
# 926 [60]
# 968 [61]
# 933 [62]
# 997 [63]
# 995 [64]
# 996 [65]
# 964 [66]
# 934 [67]
# 970 [68]
# 913 [69]
# 908 [70]
# 951 [71]
# 960 [72]
# 941 [73]
# 938 [74]
# 903 [75]
# 901 [76]
# 914 [77]
# 958 [78]
# 936 [79]
# 916 [80]
# 917 [81]
# 925 [82]
# 948 [83]
# 101 [84]
# 980 [85]
# 905 [86]
# 937 [87]
# 975 [88]
# 979 [89]
# 957 [90]
# 989 [91]
# ...

# %%
# for b in bib:
#     print(b)

# %%
# "
# „
# ”
# „”

19505 wyrazów

# %%
with open('bibliografia.txt', 'w') as f:
    f.write('\n'.join(bib))

with open('temp.txt', 'r') as f:
    text = f.read()

# %% [markdown]
# # notatki

# %%
a = [f'[{i}]' for i in range(0,100)]
a1 = [f'[0{i}]' for i in range(0,100)]
a2 = [f'[00{i}]' for i in range(0,10)]+[f'[0{i}]' for i in range(10,100)]
a3 = [f'[9{i}]' for i in range(0,10)]
a4 = [f'[90{i}]' for i in range(0,10)]+[f'[9{i}]' for i in range(10,98)]
a_vec = [a, a1, a2, a3, a4]
a_vec = [a, a1, a2, a3]
a_vec = [a4]
wyj = ['[900]', # nic nie trzeba, done
       '[930]', '[935]', # powtórki -> 90 done
       '[902]', '[931]', '[950]', # wywalić, nie będę używał done
    #    '[932]', '[934]', '[939]', '[940]' '[943]', '[944]', '[945]', '[947]', '[948]', '[984]', '[985]', '[993]' # spróbować wcisnąć
        '[946]', '[949]', '[994]' # miler done
       ]



for an in a_vec:
    for num in an:
        if num not in text and num not in wyj:
            print(num)
# Out:
# [939]
# [940]

# %%
omit = ['[930]', '[935]', # powtórki -> 90 done
        '[902]', '[931]', '[950]', # wywalić, nie będę używał done
        '[946]', '[949]', '[994]', # miler done
        '[939]', '[940]' # wywalić, nie będę używał done
        ]

# %%
wykaz_skrotow = [
    '2D',
    '3D',
    'BMS',
    'CI',
    'CRF',
    'CW',
    'HG',
    'LED',
    'LLLT',
    'MRI',
    'MSE',
    'NIR',
    'P',
    'PW',
    'RCT',
    'RMSE',
    'SMD',
    'TK',
    'VAS',
    'g - wskaźnik',
    'g - wspoółczynnik',
    'liczby losowe',
    'liczby pseudolosowe',
    'n',
    'μ_a',
    'μ_s',
    'μ_t'

]

wykaz_skrotow.sort()

for val in wykaz_skrotow:
    print(val)
# Out:
# 2D
# 3D
# BMS
# CI
# CRF
# CW
# HG
# LED
# LLLT
# MRI
# MSE
# NIR
# P
# PW
# RCT
# RMSE
# SMD
# TK
# VAS
# g - wskaźnik
# g - wspoółczynnik
# liczby losowe
# liczby pseudolosowe
# n
# μ_a
# μ_s
# μ_t

# %%
# miler 46 49 94 done
Miler monte-carlo-sim-python 46 zał. 1
Miler CUBES 49 zał. 3
monte-carlo-sim-benchmark 94 zał. 2

# %%
skuteczność luminancji

# %% [markdown]
# # nowa bibliografia

# %%
# EDYCJE NIE ZMIENIĄ KOLEJNOŚCI, BO SORT WEDŁUG alphabet!!

bib = []
alphabet = []
# 0-9
bib.append('A. van der Gijp i in., „Increasing Authenticity of Simulation-Based Assessment in Diagnostic Radiology,” Simulation in Healthcare: The Journal of the Society for Simulation in Healthcare,” t. 12, nr 6, Ovid Technologies (Wolters Kluwer Health), s. 377–384, 2017, doi: 10.1097/sih.0000000000000278.')
alphabet.append('van der Gijp')
bib.append('J. Y. Chen i in., „Non-invasive blood glucose measurement of 95% certainty by pressure regulated Mid-IR,” Talanta, t. 197, Elsevier BV, s. 211–217, 2019, doi: 10.1016/j.talanta.2019.01.034.')
alphabet.append('Chen')
bib.append('K. Tökési, L. H. Yang, D. Bo, i Z. J. Ding, „Revision of optical properties of solids based on the reverse Monte Carlo analysis of reflection electron energy loss spectroscopy spectra,” Journal of Surface Analysis, t. 26, nr 2, Surface Analysis Society of Japan, s. 128–129, 2019, doi: 10.1384/jsa.26.128.')
alphabet.append('Tökési Yang Bo Ding')
bib.append('A. N. Bashkatov, E. A. Genina, V. I. Kochubey, i V. V. Tuchin, „Optical properties of human skin, subcutaneous and mucous tissues in the wavelength range from 400 to 2000 nm,” Journal of Physics D: Applied Physics, t. 38, nr 15. IOP Publishing, s. 2543–2555, 2005, doi: 10.1088/0022-3727/38/15/004.')
alphabet.append('Bashkatov Genina Kochubey Tuchin')
bib.append('A. J. Welch i M. J. C. van Gemert, Eds., „Optical-Thermal Response of Laser-Irradiated Tissue,” Springer Netherlands, rozdz. 5, 2011 doi: 10.1007/978-90-481-8831-4.')
alphabet.append('Welch Gemert')
bib.append('E. Hecht, „Optics,” Boston: Pearson, rozdz. 4, s. 97, 2017. ISBN-13: 978-0133977226.')
alphabet.append('Hecht')
bib.append('D. O. Akpootu i in., „The Scattering and Absorption Coefficients of Atmospheric Soot in the Hygroscopicity of Urban Aerosols,” Dutse Journal of Pure and Applied Sciences, t. 9, nr 2b, African Journals Online (AJOL), s. 86–97, 2023, doi: 10.4314/dujopas.v9i2b.10.')
alphabet.append('Akpootu')
bib.append('L. Sipelgas, H. Arst, U. Raudsepp, T. Kõuts, and A. Lindfors, „Optical properties of coastal waters of northwestern Estonia: in situ measurements,” 2004.')
alphabet.append('Sipelgas Arst Raudsepp Kõuts Lindfors')
bib.append('K. M. Aly i E. Esmail, „Refractive index of salt water: effect of temperature,” Department of Engineering Mathematics and Physics, Faculty of Engineering, Alexandria University, Alexandria, Egypt, 1993.')
alphabet.append('Aly Esmail')
bib.append('T. Kono i J. Yamada, „In Vivo Measurement of Optical Properties of Human Skin for 450–800 nm and 950–1600 nm Wavelengths,” International Journal of Thermophysics, t. 40, nr 5, Springer Science and Business Media LLC, 2019. doi: 10.1007/s10765-019-2515-3.')
alphabet.append('Kono Yamada')
# 10-19
bib.append('S. Akter, „Evaluation of light scattering and absorption properties of in vivo rat liver using a single-reflectance fiber probe during preischemia, ischemia–reperfusion, and postmortem,” Journal of Biomedical Optics, t. 20, nr 7, p. 076010, 2015.')
alphabet.append('Akter')
bib.append('H. Li, L. Lin, i S. Xie, „Refractive index of human whole blood with different types in the visible and near-infrared ranges,” Biomedical Optics Laboratory, Department of Physics, Fujian Teachers University, China.')
alphabet.append('Li Lin Xie')
bib.append('C. R. Simpson, M. Kohl, M. Essenpreis, i M. Cope, „Near-infrared optical properties ofex vivohuman skin and subcutaneous tissues measured using the Monte Carlo inversion technique,” Physics in Medicine and Biology, t. 43, nr 9. IOP Publishing, s. 2465–2478, 1998, doi: 10.1088/0031-9155/43/9/003.')
alphabet.append('Simpson Kohl Essenpreis Cope')
bib.append('M. J. C. Van Gemert, S. L. Jacques, H. J. C. M. Sterenborg, i W. M. Star, „Skin optics,” IEEE Transactions on Biomedical Engineering, t. 36, nr 12. Institute of Electrical and Electronics Engineers (IEEE), s. 1146–1154, 1989. doi: 10.1109/10.42108.')
alphabet.append('Van Gemert Jacques Sterenborg')
bib.append('R. R. Anderson i B. S. J. A. Parrish, „The Optics of Human Skin,” Department of Dermatology, Harvard Medical School, Massachusetts General Hospital, Boston, Massachusetts, U.S.A., 1981. doi:10.1111/1523-1747.ep12479191.')
alphabet.append('Anderson Parrish')
bib.append('VisPy developers. (2023). Dokumentacja biblioteki VisPy [Online]. Dostęp: https://vispy.org/ [Data dostępu: 30.09.2024].')
alphabet.append('VisPy developers Dokumentacja')
bib.append('VisPy developers. (2023). Repozytorium biblioteki VisPy [Online]. Dostęp: https://github.com/vispy/vispy [Data dostępu: 30.09.2024].')
alphabet.append('VisPy developers Repozytorium')
bib.append('J. D. Hunter, „Matplotlib: A 2D Graphics Environment,” Computing in Science &amp; Engineering, t. 9, nr 3, Institute of Electrical and Electronics Engineers (IEEE), s. 90–95, 2007, doi: 10.1109/mcse.2007.55.')
alphabet.append('Hunter')
bib.append('J. Hunter, D. Dale, E. Firing, i M. Droettboom. Matplotlib development team. (2023). Dokumentacja biblioteki Matplotlib [Online]. Dostęp: https://matplotlib.org/ [Data dostępu: 30.09.2024].')
alphabet.append('Hunter Dale Firing Droettboom')
bib.append('The Matplotlib development team. (2023). Repozytorium biblioteki NumPy [Online]. Dostęp: https://github.com/matplotlib/matplotlib [Data dostępu: 30.09.2024].')
alphabet.append('Matplotlib development teamNumPy ')
# 20-29
bib.append('NumFOCUS (2023). Dokumentacja obiektu DataFrame [Online]. Dostęp: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html [Data dostępu: 30.09.2024].')
alphabet.append('NumFOCUS Pandas DataFrame')
bib.append('NumFOCUS (2023). Repozytorium biblioteki Pandas [Online]. Dostęp: https://github.com/pandas-dev/pandas [Data dostępu: 30.09.2024].')
alphabet.append('NumFOCUS Pandas Dokumentacja')
bib.append('NumFOCUS, „Strona internetowa firmy NumFOCUS rozwijającej bibliotekę Pandas,” 2023 [Online]. Dostęp: https://numfocus.org/ [Data dostępu: 30.09.2024].')
alphabet.append('NumFOCUS Pandas Repozytorium')
bib.append('NumFOCUS. (2023). Dokumentacja biblioteki Pandas [Online]. Dostęp: https://pandas.pydata.org/docs/index.html [Data dostępu: 30.09.2024].')
alphabet.append('NumFOCUS Pandas Strona internetow')
bib.append('W3C, (2023). Portable Network Graphics (PNG) Specification (Third Edition) [Online]. Dostęp: https://www.w3.org/TR/png-3/ [Data dostępu: 30.09.2024].')
alphabet.append('W3C')
bib.append('Python Software Foundation. (2023). Dokumentacja języka Python [Online]. Dostęp: https://docs.python.org/3/ [Data dostępu: 30.09.2024].')
alphabet.append('Python Dokumentacja')
bib.append('Free Software Foundation. Inc. (2008). Dokumentacja Bash [Online]. Dostęp: https://devdocs.io/bash/ [Data dostępu: 30.09.2024].')
alphabet.append('Free Software Foundation Bash Dokumentacja')
bib.append('NumPy Developers. (2022). Dokumentacja biblioteki NumPy [Online]. Dostęp: https://numpy.org/doc/stable/ [Data dostępu: 30.09.2024]')
alphabet.append('NumPy Developers')
bib.append('NumPy Developers. (2022). Dokumentacja - Permuted Congruential Generator (64-bit, PCG64) [Online]. Dostęp: https://numpy.org/doc/stable/reference/random/bit_generators/pcg64.html#permuted-congruential-generator-64-bit-pcg64 [Data dostępu: 30.09.2024].')
alphabet.append('NumPy Developers Permuted Congruential Generator')
bib.append('M. Bürmen, F. Pernuš, i P. Naglič, „MCDataset: a public reference dataset of Monte Carlo simulated quantities for multilayered and voxelated tissues computed by massively parallel PyXOpto Python package,” Journal of Biomedical Optics, t. 27, nr 08, SPIE-Intl Soc Optical Eng, 2022, doi: 10.1117/1.jbo.27.8.083012.')
alphabet.append('Bürmen Pernuš Naglič')
# 30-39
bib.append('Y. Jiang, S. L. Bugby, i J. E. Lees, „PMST: A custom Python-based Monte Carlo Simulation Tool for research and system development in portable pinhole gamma cameras,” Nuclear Instruments and Methods in Physics Research Section A: Accelerators, Spectrometers, Detectors and Associated Equipment, t. 1061, Elsevier BV, s. 169161, 2024, doi: 10.1016/j.nima.2024.169161.')
alphabet.append('Jiang Bugby Lees PMST')
bib.append('J. D. Lindberg, „The composition and optical absorption coefficient of atmospheric particulate matter,” Optical and Quantum Electronics, t. 7, nr 3, Springer Science and Business Media LLC, s. 131–139, 1975, doi: 10.1007/bf00619587.')
alphabet.append('Lindberg')
bib.append('A. Roggan, M. Friebel, K. Dörschel, A. Hahn, i G. Müller, „Optical Properties of Circulating Human Blood in the Wavelength Range 400–2500 nm,” Journal of Biomedical Optics, t. 4, nr 1. SPIE-Intl Soc Optical Eng, s. 36, 1999. doi: 10.1117/1.429919.')
alphabet.append('Roggan Friebel Dörschel Hahn Müller')
bib.append('V. V. Semak, A. Gerakis, i M. N. Shneider, „Measurement of temperature dependent absorption coefficient of water at 1064nm wavelength,” AIP Advances, t. 9, nr 8, AIP Publishing, 2019. doi: 10.1063/1.5085746.')
alphabet.append('Semak Gerakis Shneider')
bib.append('M. Bürmen, F. Pernuš, i P. Naglič, „MCDataset: a public reference dataset of Monte Carlo simulated quantities for multilayered and voxelated tissues computed by massively parallel PyXOpto Python package,” Journal of Biomedical Optics, t. 27, nr 08, SPIE-Intl Soc Optical Eng, 2022, doi: 10.1117/1.jbo.27.8.083012.')
alphabet.append('Bürmen Pernuš Naglič')
bib.append('O. N. Vassiliev, „Monte Carlo Methods for Radiation Transport,” Springer International Publishing, 2017, doi: 10.1007/978-3-319-44141-2.')
alphabet.append('Vassiliev')
bib.append('A. J. Welch i M. J. C. van Gemert, Red, „Optical-Thermal Response of Laser-Irradiated Tissue,” Springer Netherlands, 2011, doi: 10.1007/978-90-481-8831-4.')
alphabet.append('Welch Gemert')
bib.append('A. P. Tran i S. L. Jacques, „Modeling voxel-based Monte Carlo light transport with curved and oblique boundary surfaces,” Journal of Biomedical Optics, t. 25, nr 02, SPIE-Intl Soc Optical Eng, s. 1, 2020, doi: 10.1117/1.jbo.25.2.025001.')
alphabet.append('Tran Jacques')
bib.append('D. E. Knuth, „The Art of Computer Programming, Volume 1 (3rd ed.): Fundamental Algorithms,” Addison Wesley Longman Publishing Co., Inc., USA, 1997.')
alphabet.append('Knuth')
bib.append('W. T. Vetterling, „Numerical Recipes Example Book (c),” Cambridge (Mass.): Cambridge University Press, 1995.')
alphabet.append('Vetterling')
# 40-49
bib.append('The Free Dictionary. Medical Dictionary [Online]. Dostęp: https://medical-dictionary.thefreedictionary.com/ [Data dostępu: 30.09.2024].')
alphabet.append('The Free Dictionary')
bib.append('Broszura dla nauczycieli o tematyce optyki [Online]. Dostęp: https://zpe.gov.pl/pdf/Pmx9E7pqe [Data dostępu: 30.09.2024].')
alphabet.append('Broszura dla nauczycieli o tematyce optyki')
bib.append('ISO/IEC 9899:2018, Programming Languages — C, 2018.')
alphabet.append('C ISO/IEC 9899:2018')
bib.append('cppreference.com. .C Documentation [Online]. Dostęp: https://en.cppreference.com/w/c/language [Data dostępu: 30.09.2024].')
alphabet.append('cppreference.com')
bib.append('DevDocs. C Documentation [Online]. Dostęp: https://devdocs.io/c/ [Data dostępu: 30.09.2024].')
alphabet.append('DevDocs')
bib.append('M. Miler, „monte-carlo-sim-python - repozytorium z własną implementacją symulacji światła metodą Monte Carlo w języku Python,” GitHub [Online]. Dostęp: https://github.com/Mateuszq28/monte-carlo-sim-python [Data dostępu: 30.09.2024].')
alphabet.append('Miler monte-carlo-sim-python')
bib.append('ECMA-404. The JSON Data Interchange Syntax [Online]. Dostęp: https://ecma-international.org/publications-and-standards/standards/ecma-404/ [Data dostępu: 30.09.2024].')
alphabet.append('ECMA-404')
bib.append('W3Schools. W3Schools - JSON Introduction [Online]. Dostęp: https://www.w3schools.com/js/js_json_intro.asp [Data dostępu: 30.09.2024].')
alphabet.append('W3Schools')
bib.append('M. Miler, „CUBES - wyniki najważniejszych eksperymentów symulacji światła metodą Mone Carlo” Google Drive [Online]. Dostęp: https://1drv.ms/f/c/7871da7edeb06dcc/Ei70d6guE4lBgMsf6FgGbJsBUcYmqrgZFZZxBHvQeMgqBQ [Data dostępu: 30.09.2024].')
alphabet.append('Miler CUBES')
bib.append('T. L. Stedman, Stedman’s Medical Dictionary, Philadelphia: Lippincott Williams & Wilkins, 2006.')
alphabet.append('Stedman')
# 50-59
bib.append('V. Sontea, I. Pocaznoi, D. Furtuna, A. Seryakov, V. Barun, i S. Dick, „Effects of the Low Level Light therapy on skin wound using LED,” 2013 E-Health and Bioengineering Conference (EHB), t. 100, IEEE, 2013, doi: 10.1109/ehb.2013.6707243.')
alphabet.append('Sontea Pocaznoi Furtuna Seryakov Barun Dick')
bib.append('P. Zhang i M. X. Wu, „A clinical review of phototherapy for psoriasis,” Lasers in Medical Science, t. 33, nr 1. Springer Science and Business Media LLC, s. 173–180, 2017, doi: 10.1007/s10103-017-2360-1.')
alphabet.append('Zhang Wu')
bib.append('T. Niu, Y. Tian, Q. Ren, L. Wei, X. Li, i Q. Cai, „Red Light Interferes in UVA‐Induced Photoaging of Human Skin Fibroblast Cells,” Photochemistry and Photobiology, t. 90, nr 6. Wiley, s. 1349–1358, 2014, doi: 10.1111/php.12316.')
alphabet.append('Niu Tian Ren Wei Li Cai')
bib.append('H. H. Kwon i in., „The clinical and histological effect of home-use, combination blue-red LED phototherapy for mild-to-moderate acne vulgaris in Korean patients: a double-blind, randomized controlled trial,” British Journal of Dermatology, t. 168, nr 5, Oxford University Press (OUP), s. 1088–1094, 2013, doi: 10.1111/bjd.12186.')
alphabet.append('Kwon')
bib.append('C. Lu i in., „Effects of low-level laser therapy on burning pain and quality of life in patients with burning mouth syndrome: a systematic review and meta-analysis,” BMC Oral Health, t. 23, nr 1, Springer Science and Business Media LLC, 2023, doi: 10.1186/s12903-023-03441-w.')
alphabet.append('Lu')
bib.append('T.-W. Hou, C.-C. Yang, T.-H. Lai, Y.-H. Wu, i C.-P. Yang, „Light Therapy in Chronic Migraine,” Current Pain and Headache Reports, t. 28, nr 7, Springer Science and Business Media LLC, s. 621–626, 2024, doi: 10.1007/s11916-024-01258-y.')
alphabet.append('Hou Yang Lai Wu Yang')
bib.append('P. Xiao i in., „Effect of Light Therapy on Cancer-Related Fatigue: A Systematic Review and Meta-Analysis,” Journal of Pain and Symptom Management, t. 63, nr 2, Elsevier BV, s. e188–e202, 2022, doi: 10.1016/j.jpainsymman.2021.09.010.')
alphabet.append('Xiao')
bib.append('A. van Maanen, A. M. Meijer, K. B. van der Heijden, i F. J. Oort, „The effects of light therapy on sleep problems: A systematic review and meta-analysis,” Sleep Medicine Reviews, t. 29, Elsevier BV, s. 52–62, 2016, doi: 10.1016/j.smrv.2015.08.009.')
alphabet.append('van Maanen Meijer van der Heijden Oort')
bib.append('E. Pjrek i in., „The Efficacy of Light Therapy in the Treatment of Seasonal Affective Disorder: A Meta-Analysis of Randomized Controlled Trials,” Psychotherapy and Psychosomatics, t. 89, nr 1. S. Karger AG, s. 17–24, 2019, doi: 10.1159/000502891.')
alphabet.append('Pjrek')
bib.append('L. Tao i in., „Light therapy in non-seasonal depression: An update meta-analysis,” Psychiatry Research, t. 291, Elsevier BV, s. 113247, 2020, doi: 10.1016/j.psychres.2020.113247.')
alphabet.append('Tao')
# 60-69
bib.append('S. Dallaspezia i F. Benedetti, „Antidepressant light therapy for bipolar patients: A meta-analyses,” Journal of Affective Disorders, t. 274, Elsevier BV, s. 943–948, 2020, doi: 10.1016/j.jad.2020.05.104.')
alphabet.append('Dallaspezia Benedetti')
bib.append('A. Brouwer i in., „Light therapy: is it safe for the eyes?,” Acta Psychiatrica Scandinavica, t. 136, nr 6, Wiley, s. 534–548, 2017, doi: 10.1111/acps.12785.')
alphabet.append('Brouwer')
bib.append('P. Avci, A. Gupta, M. Sadasivam, D. Vecchio, Z. Pam, N. Pam, and M. R. Hamblin, „Low-level laser (light) therapy (LLLT) in skin: stimulating, healing, restoring,” Seminars in Cutaneous Medicine and Surgery, t. 32, nr 1, s. 41–52, 2013.')
alphabet.append('Avci Gupta Sadasivam Vecchio Pam Pam Hamblin')
bib.append('Scratchapixel. Monte Carlo Methods in Practice [Online]. Dostęp: https://www.scratchapixel.com/lessons/mathematics-physics-for-computer-graphics/monte-carlo-methods-in-practice/monte-carlo-simulation.html [Data dostępu: 30.09.2024].')
alphabet.append('Scratchapixel')
bib.append('MarbleScience. YouTube. (grafika z filmu). Monte Carlo Simulation [Online]. Dostęp: https://www.youtube.com/watch?v=7ESK5SaP-bc [Data dostępu: 30.09.2024].')
alphabet.append('MarbleScience')
bib.append('MathWorks. Funkcja obliqueslice programu MATLAB [Online]. Dostęp: https://www.mathworks.com/help/images/ref/obliqueslice.html#mw_dd35cbdb-0566-4cd9-8a4f-31d452f3b621 [Data dostępu: 30.09.2024].')
alphabet.append('MathWorks obliqueslice')
bib.append('N. Metropolis, „The beginning of the Monte Carlo method,” Los Alamos Science, t. 15, nr Special issue, s. 125–130, 1987.')
alphabet.append('Metropolis')
bib.append('R. D. Richtmyer i J. von Neumann, „Statistical methods in neutron diffusion,” Los Alamos Scientific Laboratory Report LAMS-551, Los Alamos, 1947.')
alphabet.append('Richtmyer, von Neumann')
bib.append('R. Eckhardt, „Stan Ulam, John von Neumann, and the Monte Carlo method,” 1987.')
alphabet.append('Eckhardt')
bib.append('E. Sergè, „From X-Rays to Quarks: Modern Physicists and Their Discoveries,” Dover, Mineola, NY, rozdz. 10, s. 200, 2007. ISBN-13: 978-0486457833.')
alphabet.append('Sergè')
# 70-79
bib.append('J. Baro, J. Sempau, J. M. Fernandez-Varea, and F. Salvat, „PENELOPE: an algorithm for Monte Carlo simulation of the penetration and energy loss of electrons and positrons in matter,” Nuclear Instruments and Methods in Physics Research Section B, t. 100, nr 1, s. 31–46, 1995.')
alphabet.append('Baro Sempau  Fernandez-Varea Salvat')
bib.append('N. Metropolis i S. Ulam, „The Monte Carlo Method,” Journal of the American Statistical Association, t. 44, nr 247. Informa UK Limited, s. 335–341, 1949, doi: 10.1080/01621459.1949.10483310.')
alphabet.append('Metropolis Ulam')
bib.append('A. Marrs, P. Shirley, and I. Wald, Eds., „Ray tracing gems II: Next generation real-time rendering with DXR, vulkan, and OptiX,” Berlin, Germany: APress, rozdz. 8, s. 104. 2021. ISBN: 978-1-4842-7184-1.')
alphabet.append('Marrs Shirley Wald')
bib.append('P. Comninos, „Mathematical and Computer Programming Techniques for Computer Graphics,” London: Springer London, rozdz. 10, s. 361, 2010. ISBN-13: 978-1-8233-902-9.')
alphabet.append('Comninos')
bib.append('Wikipedia. Marching Cubes [Online]. Dostęp: https://en.wikipedia.org/wiki/Marching_cubes [Data dostępu: 30.09.2024].')
alphabet.append('Wikipedia')
bib.append('W. E. Lorensen i H. E. Cline, „Marching cubes: A high resolution 3D surface construction algorithm,” Proceedings of the 14th annual conference on Computer graphics and interactive techniques, ACM, 1987, doi: 10.1145/37401.37422.')
alphabet.append('Lorensen Cline')
bib.append('Algorithms Visualized. YouTube. Marching Cubes Animation [Online]. Dostęp: https://www.youtube.com/watch?v=B_xk71YopsA [Data dostępu: 30.09.2024].')
alphabet.append('Algorithms Visualized')
bib.append('DV Gen. YouTube. Why I\'m Using Wave Function Collapse for Procedural Terrain | Unity Devlog [Online]. Dostęp: https://www.youtube.com/watch?v=20KHNA9jTsE&list=PLWviGNkmY14wquTDA46Ycjq_p-B2Cew8S&index=3&t=4s [Data dostępu: 30.09.2024].')
alphabet.append('DV Gen')
bib.append('D. Williamson. MarchingCubes.js [Online]. Dostęp: https://gist.github.com/dwilliamson/c041e3454a713e58baf6e4f8e5fffecd [Data dostępu: 30.09.2024]')
alphabet.append('Williamson')
bib.append('L. Wang i S. L. Jacques. Optical Imaging Laboratory. Biomedical Engineering Program. Texas A&M University. College Station. TX 77843-3120. Monte Carlo Modeling of Light Transport in Multi-layered Tissues in Standard C [Online]. Dostęp: https://omlc.org/software/mc/man_mcml.pdf [Data dostępu: 30.09.2024].')
alphabet.append('Wang Jacques')
# 80-89
bib.append('OMLC. Symulacja MC321 [Online]. Dostęp: https://omlc.org/classroom/ece532/class4/ssmc/index.html [Data dostępu: 30.09.2024].')
alphabet.append('OMLC MC321”')
bib.append('OMLC. Symulacja MCXYZ [Online]. Dostęp: https://omlc.org/software/mc/mcxyz/index.html [Data dostępu: 30.09.2024].')
alphabet.append('OMLC MCXYZ”')
bib.append('OMLC. Symulacja MCML [Online]. Dostęp: https://omlc.org/software/mc/mcml-src/index.html [Data dostępu: 30.09.2024].')
alphabet.append('OMLC MCML”')
bib.append('OMLC [Online]. Dostęp: https://omlc.org/software/mc/ [Data dostępu: 30.09.2024]')
alphabet.append('OMLC')
bib.append('M. Keijzer, S. L. Jacques, S. A. Prahl, i A. J. Welch, „Light distributions in artery tissue: Monte Carlo simulations for finite‐diameter laser beams,” Lasers in Surgery and Medicine, t. 9, nr 2. Wiley, s. 148–154, 1989, doi: 10.1002/lsm.1900090210.')
alphabet.append('Keijzer Jacques Prahl Welch')
bib.append('Octave [Online]. Dostęp: https://octave.org/ [Data dostępu: 30.09.2024].')
alphabet.append('Octave')
bib.append('MathWorks. MATLAB [Online]. Dostęp: https://www.mathworks.com/products/matlab.html [Data dostępu: 30.09.2024]')
alphabet.append('MathWorks MATLAB')
bib.append('DCC-Lab. GitHub. PyTissueOptics [Online]. Dostęp: https://github.com/DCC-Lab/PyTissueOptics [Data dostępu: 30.09.2024].')
alphabet.append('DCC-Lab')
bib.append('xopto. GitHub. PyXOpto [Online]. Dostęp: https://github.com/xopto/pyxopto [Data dostępu: 30.09.2024].')
alphabet.append('xopto')
bib.append('M. Bürmen, F. Pernuš, i P. Naglič, „MCDataset: a public reference dataset of Monte Carlo simulated quantities for multilayered and voxelated tissues computed by massively parallel PyXOpto Python package,” Journal of Biomedical Optics, t. 27, nr 08, SPIE-Intl Soc Optical Eng, 2022, doi: 10.1117/1.jbo.27.8.083012.')
alphabet.append('Bürmen Pernuš Naglič')
# 90-99
bib.append('P. Naglič, F. Pernuš, B. Likar, i M. Bürmen, „Limitations of the commonly used simplified laterally uniform optical fiber probe-tissue interface in Monte Carlo simulations of diffuse reflectance,” Biomedical Optics Express, t. 6, nr 10, Optica Publishing Group, s. 3973, 2015, doi: 10.1364/boe.6.003973.')
alphabet.append('Naglič Pernuš Likar Bürmen Limitations of the commonly used simplified laterally uniform optical fiber probe-tissue interface')
bib.append('P. Naglič, F. Pernuš, B. Likar, i M. Bürmen, „Lookup table-based sampling of the phase function for Monte Carlo simulations of light propagation in turbid media,” Biomedical Optics Express, t. 8, nr 3. Optica Publishing Group, s. 1895, 2017, doi: 10.1364/boe.8.001895.')
alphabet.append('Naglič Pernuš Likar Bürmen Lookup table-based sampling')
bib.append('OMLC. Kod źródłowy symulacji Tiny [Online]. Dostęp: https://omlc.org/software/mc/tiny_mc.c [Data dostępu: 30.09.2024].')
alphabet.append('OMLC Tiny')
bib.append('M. Miler. GitHub. monte-carlo-sim-benchmark - repozytorium wykorzystane do porównywania wyników symulacji [Online]. Dostęp: https://github.com/Mateuszq28/monte-carlo-sim-benchmark [Data dostępu: 30.09.2024].')
alphabet.append('Miler monte-carlo-sim-benchmark')
bib.append('SciPy. Funkcja z transformacją Box-Cox [Online]. Dostęp: https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.boxcox.html [Data dostępu: 30.09.2024].')
alphabet.append('SciPy Box-Cox')
bib.append('SciPy. Funkcja z transformacją Yeo-Johnson [Online]. Dostęp: https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.yeojohnson.html [Data dostępu: 30.09.2024].')
alphabet.append('SciPy Yeo-Johnson')
bib.append('Scikit-learn. QuantileTransformer [Online]. Dostęp: https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.QuantileTransformer.html [Data dostępu: 30.09.2024].')
alphabet.append('Scikit-learn QuantileTransformer')
bib.append('Anaconda, Menadżer środowiska wirtualnego oraz pakietów dla języka Python [Online]. Dostęp: https://www.anaconda.com/ [Data dostępu: 30.09.2024].')
alphabet.append('Anaconda')
bib.append('cpp0x. Funkcja rand z biblioteki standardowej języka C [Online]. Dostęp: https://cpp0x.pl/dokumentacja/standard-C/rand/580 [Data dostępu: 30.09.2024].')
alphabet.append('cpp0x rand')
bib.append('M. Goun. Biblioteka Geometry3D dla języka Python [Online]. Dostęp: https://geometry3d.readthedocs.io/en/latest/about.html [Data dostępu: 30.09.2024].')
alphabet.append('Goun Geometry3D')
# 100-109
bib.append('W3schools. .Python Dictionaries [Online]. Dostęp: https://www.w3schools.com/python/python_dictionaries.asp [Data dostępu: 30.09.2024].')
alphabet.append('W3schools Python Dictionaries')
bib.append('Photonics. Internetowy kalkulator Lux-Wat [Online]. Dostęp: https://www.gophotonics.com/calculators/lux-to-watts-conversion-calculator [Data dostępu: 30.09.2024].')
alphabet.append('Photonics')


bib_arr = np.array(bib)
print('bib_arr', len(bib_arr))
bib_arr_unique = np.unique(bib_arr)
print('bib_arr', 'unique', len(bib_arr_unique))
print()

alphabet_arr = np.array(alphabet)
print('alphabet_arr', len(alphabet_arr))
alphabet_arr_unique = np.unique(alphabet_arr)
print('alphabet_arr', 'unique', len(alphabet_arr_unique))
print()

alphabet_duplicates = (Counter(alphabet) - Counter(set(alphabet))).keys()
bib_duplicates = (Counter(bib) - Counter(set(bib))).keys()

print('alphabet_duplicates') # 30 35
print(alphabet_duplicates)
print(len(alphabet_duplicates))
print()

print('bib_duplicates') # 30 35
print(bib_duplicates)
print(len(bib_duplicates))
print()






omit = ['[930]', '[935]', # powtórki -> 90 done
        '[902]', '[931]', '[950]', # wywalić, nie będę używał done
        '[946]', '[949]', '[994]', # miler done
        '[939]', '[940]' # wywalić, nie będę używał done
        ]

omit_id = [930, 935, # powtórki -> 90 done
           902, 931, 950, # wywalić, nie będę używał done
           946, 949, 994, # miler done
           939, 940 # wywalić, nie będę używał done
           ]




# old num arr/list
num_200 = [f'[90{i}]' for i in range(1,10)] + [f'[9{i}]' for i in range(10,100)] + [f'[{i}]' for i in range(100,201)]
n = len(bib)
num_old = num_200[:n]
num_old_arr = np.array(num_old)

# mask - filter out bad vals
mask = np.ones(shape=alphabet_arr.shape)
omit_id_arr = np.array(omit_id)
mask[omit_id_arr-900-1] = 0
mask = mask.astype(bool)

# filter out
filtered_alphabet_arr = alphabet_arr[mask]
filtered_bib_arr = bib_arr[mask]
filtered_num_old_arr = num_old_arr[mask]

# sort idx
sort_index = np.argsort(np.char.upper(filtered_alphabet_arr))

# sort all
sorted_alphabet_arr = filtered_alphabet_arr[sort_index]
sorted_bib_arr = filtered_bib_arr[sort_index]
sorted_num_old_arr = filtered_num_old_arr[sort_index]

# new num arr
n = len(sorted_bib_arr)
new_num_arr = np.array([f'[{i+1}]' for i in range(n)])
# Out:
# bib_arr 102
# bib_arr unique 100
#
# alphabet_arr 102
# alphabet_arr unique 99
#
# alphabet_duplicates
# dict_keys(['Welch Gemert', 'Bürmen Pernuš Naglič'])
# 2
#
# bib_duplicates
# dict_keys(['M. Bürmen, F. Pernuš, i P. Naglič, „MCDataset: a public reference dataset of Monte Carlo simulated quantities for multilayered and voxelated tissues computed by massively parallel PyXOpto Python package”, Journal of Biomedical Optics, t. 27, nr 08. SPIE-Intl Soc Optical Eng, 2022. doi: 10.1117/1.jbo.27.8.083012.'])
# 1

# %%
5 wywalić i zastąpić nr 37 (wg numeracji obsidian)
905 [86]
937 [87]
czyli
86 wywalić i zmienić na 87

# %%
with open('bib_2.txt', 'w') as f:
    f.write('\n'.join(sorted_bib_arr))

# %%
wywalić:
16
19
23
28
38
39
40
47
48
60
81
82
83
84
86



od 103 do 117 dodać

# %%
# dodanie od 103 do 117
add_bib = []
add_alphabet = []

# 103
add_bib.append('S. L. Jacques, „Light distributions from point, line and plane sources for photochemical reactions and fluorescence in turbid biological tissues,” Photochem. Photobiol., t. 67, s. 23-32, 1998.')
alphabet.append('Jacques S L Light distributions from point, line and plane')
# 104
add_bib.append('S. E. Umbaugh, „Digital image processing and analysis: Digital image enhancement, restoration and compression,” rozdz. 6.4, s. 272-279, London, England: CRC Press, 2022. ISBN: 1-000-78991-8.')
alphabet.append('Umbaugh S E Digital image processing and analysis: Digital image enhancement')
# 105
add_bib.append('U. Kose, O. Deperlioglu, and D. J. Hemanth, „Deep Learning for Biomedical Applications,” rozdz. 13, s. 283. Boca Raton: CRC Press, 2021. ISBN : 0-367-85561-5.')
alphabet.append('Kose Deperlioglu Hemanth U O D J Deep Learning for Biomedical Application')
# 106
add_bib.append('S. V. Shinde, V. Bendre, D. Jude Hemanth, and M.-A. Balafar, „Applied artificial intelligence: A biomedical Perspective,” rozdz. 2 s. 19. 2023. ISBN : 1-003-32443-6.')
alphabet.append('Shinde Bendre Jude Hemanth Balafar')
# 107
add_bib.append('S. Dash, S. K. Pani, J. Rodrigues, and B. Majhi, „Deep learning, Machine Learning and IoT in biomedical and Health Informatics: Techniques and applications,” rozdz. 2, s. 21, Boca Raton, FL: CRC Press, 2022. ISBN 9780367548469.')
alphabet.append('Dash Pani Rodrigues Majhi')
# 108
add_bib.append('')
alphabet.append('')
# 109
add_bib.append('C. Andersson Naesseth, „Machine learning using approximate inference : Variational and sequential Monte Carlo methods,” rozdz. 3, s. 25, Linköping: Linköping University Electronic Press, 2018. ISBN : 9789176851616.')
alphabet.append('Andersson Naesseth „Machine learning using approximate')
# 110
add_bib.append('P. Cirrone and G. Petringa, Eds., „Monte Carlo in heavy charged particle therapy: New challenges in ion therapy,” rozdz. 16, s. 240, London, England: CRC Press, 2024. ISBN : 1-000-98761-2.')
alphabet.append('Cirrone Petringa Eds Monte Carlo in heavy charged ')
# 111
add_bib.append('')
alphabet.append('')
# 112
add_bib.append('M. R. Hamblin, T. Agrawal, and M. de Sousa, Eds., „Handbook of low-level laser therapy. Singapore, Singapore: Pan Stanford Publishing,” rozdz. 1, s. 7, 2021. ISBN : 9786612930713.')
alphabet.append('Hamblin Agrawal Sousa')
# 113
add_bib.append('P. D. Lin, „New Computation Methods for Geometrical Optics,” rozdz. 3, s. 17, Springer Singapore, 2014. ISBN : 981-4451-79-7.')
alphabet.append('Lin P D New Computation Methods')
# 114
add_bib.append('')
alphabet.append('')
# 115
add_bib.append('G. Hart-Davis and T. Hart-Davis, „Python,” rozdz. 1, s. 18, Hoboken, NJ, USA: John Wiley & Sons Inc., 2022. ISBN : 1-119-86026-1.')
alphabet.append('Hart-Davis Hart-Davis Python')
# 116
add_bib.append('A. Stevens, „Monte-Carlo Simulation: An Introduction for Engineers and Scientists,” rozdz. 7, s. 33, Boca Raton, FL, USA: CRC Press, 2023. ISBN: 1-03-228077-8.')
alphabet.append('Stevens Monte-Carlo Simulation')
# 117
add_bib.append('F.-B. Yang and J.-P. Huang, „Diffusionics: Diffusion Process Controlled by Diffusion Metamaterials,” rozdz. 1, s. 18, Springer Singapore, 2024. ISBN: 981-9704-86-3.')
alphabet.append('Yang Huang Diffusionics')



len_add = len(add_bib)
len_old = len(sorted_bib_arr)
add_bib_arr = np.array(add_bib)
alphabet_arr = np.array(alphabet)
add_num_arr = list(range(103,118))


alphabet_arr30 = np.hstack([sorted_alphabet_arr, add_bib_arr])
bib_arr30 = np.hstack([sorted_bib_arr, add_bib_arr])
num_old_arr30 = np.hstack([sorted_num_old_arr, add_num_arr])



# old num arr/list
num_200 = [f'[90{i}]' for i in range(1,10)] + [f'[9{i}]' for i in range(10,100)] + [f'[{i}]' for i in range(100,201)]
n = len(bib)
num_old = num_200[:n]
num_old_arr = np.array(num_old)

# mask - filter out bad vals
mask = np.ones(shape=alphabet_arr.shape)
omit_id_arr = np.array(omit_id)
mask[omit_id_arr-900-1] = 0
mask = mask.astype(bool)

# filter out
filtered_alphabet_arr = alphabet_arr[mask]
filtered_bib_arr = bib_arr[mask]
filtered_num_old_arr = num_old_arr[mask]

# sort idx
sort_index = np.argsort(np.char.upper(filtered_alphabet_arr))

# sort all
sorted_alphabet_arr = filtered_alphabet_arr[sort_index]
sorted_bib_arr = filtered_bib_arr[sort_index]
sorted_num_old_arr = filtered_num_old_arr[sort_index]

# %%
import numpy as np

a = np.array([1,2,3])
b = np.array([5,6,7])
np.hstack([a,b])
# Out:
# array([1, 2, 3, 5, 6, 7])

# %%
del 114 111 108


17 książek -

# %% [markdown]
# #### hide

# %%
106, 107 - ai ogólne preprocessing obrazów
108 - Fototerapia wykazuje także skuteczność w leczeniu zaburzeń depresyjnych
109 - Kolejnym kierunkiem badań mogłaby być nie tylko rekonstrukcja obrazu, ale także próba przewidywania zachowania fotonu z pomocą uczenia maszynowego [109].
110 - . Do przybliżenia tych zjawisk świetnie nadaje się metoda Monte Carlo [110]. 
111 - Wiele prac wykazało, że w terapii światłem o niskim poziomie mocy (ang. low-level laser (light) therapy - LLLT) elektrony mitochondrialne działają jako układ fotoakceptorowy, będąc światłoczułym na światło czerwone i bliskiej podczerwieni (ang. near-infrared light - NIR) [111]. 
112,113 - Wzory opisujące wektory kierunku odbicia i załamania wiązki światła opatrzono numerami 2.4-5 [14,37][112][113].
115 - W pracy należało wykonać symulacje numeryczne w języku Python [60][115] 
116 - Metoda Monte Carlo ma oczywiście wiele zastosowań. Można jej nawet użyć do obliczenia pola powierzchni skomplikowanej figury geometrycznej (rys. 2.3) [116]. 
117 - Inną popularną metodą, która dobrze oddaje naturę wymienionych zjawisk i jest równie wydajna obliczeniowo – jest metoda dyfuzyjna [117]. 






DONE
104 - filtr medianowy
105 -The Effects of Image Pre-processing in Detection of Brain
Tumors Using Faster R-CNN on Magnetic Resonance Scans.........283
Emre Dandıl and Süleyman Uzun

106 - Chapter 2 AI-Based Healthcare: Top Businesses and Technologies .................. 19
Dipali Ghatge and K. Rajeswari

107 big picture

111
Chapter 16 Towards multiple ion applications in particle therapy......................................... 240
Taku Inaniw
